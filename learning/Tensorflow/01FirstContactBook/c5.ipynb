# %%
import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
import tensorflow as tf


x = tf.placeholder("float", shape=[None, 784])
y_ = tf.placeholder("float", shape=[None, 10])

x_image = tf.reshape(x, [-1,28,28,1])
print "x_image="
print x_image

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])



h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)


W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)


W_fc1 = weight_variable([7 * 7 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)


keep_prob = tf.placeholder("float")
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)


W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])

y_conv=tf.nn.softmax(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)


cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))

sess = tf.Session()

sess.run(tf.initialize_all_variables())
for i in range(200):
    batch = mnist.train.next_batch(50)
    if i%10 == 0:
        train_accuracy = sess.run( accuracy, feed_dict={x:batch[0], y_: batch[1], keep_prob: 1.0})
    print("step %d, training accuracy %g"%(i, train_accuracy))

    sess.run(train_step,feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

    print("test accuracy %g"% sess.run(accuracy, feed_dict={
    x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# /home/diego/anaconda2/lib/python2.7/gzip.py:275: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   chunk = self.extrabuf[offset: offset + size]
# input_data.py:55: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   data = data.reshape(num_images, rows, cols, 1)
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# x_image=
# Tensor("Reshape:0", shape=(?, 28, 28, 1), dtype=float32)
# step 0, training accuracy 0.06
# test accuracy 0.0856
# step 1, training accuracy 0.06
# test accuracy 0.1008
# step 2, training accuracy 0.06
# test accuracy 0.0975
# step 3, training accuracy 0.06
# test accuracy 0.1078
# step 4, training accuracy 0.06
# test accuracy 0.117
# step 5, training accuracy 0.06
# test accuracy 0.1245
# step 6, training accuracy 0.06
# test accuracy 0.135
# step 7, training accuracy 0.06
# test accuracy 0.1571
# step 8, training accuracy 0.06
# test accuracy 0.1773
# step 9, training accuracy 0.06
# test accuracy 0.1957
# step 10, training accuracy 0.18
# test accuracy 0.2251
# step 11, training accuracy 0.18
# test accuracy 0.2708
# step 12, training accuracy 0.18
# test accuracy 0.3113
# step 13, training accuracy 0.18
# test accuracy 0.3452
# step 14, training accuracy 0.18
# test accuracy 0.3761
# step 15, training accuracy 0.18
# test accuracy 0.3917
# step 16, training accuracy 0.18
# test accuracy 0.3976
# step 17, training accuracy 0.18
# test accuracy 0.3999
# step 18, training accuracy 0.18
# test accuracy 0.4078
# step 19, training accuracy 0.18
# test accuracy 0.418
# step 20, training accuracy 0.46
# test accuracy 0.4311
# step 21, training accuracy 0.46
# test accuracy 0.451
# step 22, training accuracy 0.46
# test accuracy 0.4872
# step 23, training accuracy 0.46
# test accuracy 0.5141
# step 24, training accuracy 0.46
# test accuracy 0.5356
# step 25, training accuracy 0.46
# test accuracy 0.5554
# step 26, training accuracy 0.46
# test accuracy 0.5693
# step 27, training accuracy 0.46
# test accuracy 0.5765
# step 28, training accuracy 0.46
# test accuracy 0.5816
# step 29, training accuracy 0.46
# test accuracy 0.5943
# step 30, training accuracy 0.64
# test accuracy 0.6106
# step 31, training accuracy 0.64
# test accuracy 0.6269
# step 32, training accuracy 0.64
# test accuracy 0.6474
# step 33, training accuracy 0.64
# test accuracy 0.6652
# step 34, training accuracy 0.64
# test accuracy 0.68
# step 35, training accuracy 0.64
# test accuracy 0.693
# step 36, training accuracy 0.64
# test accuracy 0.7009
# step 37, training accuracy 0.64
# test accuracy 0.705
# step 38, training accuracy 0.64
# test accuracy 0.7069
# step 39, training accuracy 0.64
# test accuracy 0.7119
# step 40, training accuracy 0.64
# test accuracy 0.7121
# step 41, training accuracy 0.64
# test accuracy 0.7127
# step 42, training accuracy 0.64
# test accuracy 0.7097
# step 43, training accuracy 0.64
# test accuracy 0.7008
# step 44, training accuracy 0.64
# test accuracy 0.6984
# step 45, training accuracy 0.64
# test accuracy 0.6954
# step 46, training accuracy 0.64
# test accuracy 0.7
# step 47, training accuracy 0.64
# test accuracy 0.7061
# step 48, training accuracy 0.64
# test accuracy 0.7189
# step 49, training accuracy 0.64
# test accuracy 0.7326
# step 50, training accuracy 0.64
# test accuracy 0.7423
# step 51, training accuracy 0.64
# test accuracy 0.7484
# step 52, training accuracy 0.64
# test accuracy 0.7514
# step 53, training accuracy 0.64
# test accuracy 0.7572
# step 54, training accuracy 0.64
# test accuracy 0.7627
# step 55, training accuracy 0.64
# test accuracy 0.7674
# step 56, training accuracy 0.64
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b92dd075a7b6> in <module>()
#      76
#      77     print("test accuracy %g"% sess.run(accuracy, feed_dict={
# ---> 78     x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
#
# /home/diego/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/diego/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/diego/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/diego/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     713   def _do_call(self, fn, *args):
#     714     try:
# --> 715       return fn(*args)
#     716     except errors.OpError as e:
#     717       message = compat.as_text(e.message)
#
# /home/diego/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     695         return tf_session.TF_Run(session, options,
#     696                                  feed_dict, fetch_list, target_list,
# --> 697                                  status, run_metadata)
#     698
#     699     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
